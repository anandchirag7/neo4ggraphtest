# %%
euri_api_key = "euri-a1d04833d1748505045e19d2ad09a30e2b0b1b8877b4178a3b19187dc7e275b2"

# %%
import os, json, time, sqlite3, warnings
from typing import Dict, Any, List
import re
import easyocr
import fitz # PyMuPDF
# from euriai.langgraph import EuriaiLangGraph

# %%
from euriai.langgraph import EuriaiLangGraph

# %%
EURI_API_KEY  = "euri-a1d04833d1748505045e19d2ad09a30e2b0b1b8877b4178a3b19187dc7e275b2"
MODEL         = "gpt-4.1-nano"

# %%
INPUT_DIR     = "invoices"
DB_PATH       = "invoice.sqlite" 
PROCESSED_LOG = "processed.json"
POLL_SEC      = 5

# %%
os.makedirs(INPUT_DIR, exist_ok=True)

# %%
def load_seen() -> set:
    if not os.path.exists(PROCESSED_LOG):
        return set()
    try:
        with open(PROCESSED_LOG, "r", encoding="utf-8") as f:
            return set(json.load(f))
    except Exception:
        return set()

# %%
def save_seen(seen: set) -> None:
    with open(PROCESSED_LOG, "w", encoding="utf-8") as f:
        json.dump(sorted(list(seen)), f, ensure_ascii=False, indent=2)
        
seen = load_seen()

# %%
def ensure_schema():
    con = sqlite3.connect(DB_PATH)
    cur = con.cursor()
    # Create if missing
    cur.execute(
        """
        CREATE TABLE IF NOT EXISTS invoices (
          id INTEGER PRIMARY KEY AUTOINCREMENT,
          file_name TEXT,
          vendor TEXT,
          number TEXT,
          date TEXT,
          total REAL,
          currency TEXT,
          raw_json TEXT
        )
        """
    )
    # Add columns if table existed with an older schema
    cur.execute("PRAGMA table_info(invoices);")
    cols = {row[1] for row in cur.fetchall()}
    if "file_name" not in cols:
        cur.execute("ALTER TABLE invoices ADD COLUMN file_name TEXT;")
    if "raw_json" not in cols:
        cur.execute("ALTER TABLE invoices ADD COLUMN raw_json TEXT;")
    con.commit()
    con.close()

ensure_schema()

# %%
ocr = easyocr.Reader(["en"], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
clean_graph = EuriaiLangGraph(api_key=EURI_API_KEY, default_model=MODEL)
clean_graph.add_ai_node(
    "CLEAN",
    """You clean noisy OCR to plain text.
- Keep facts.
- No guessing.
- Keep table rows readable.

OCR:
{ocr_text}"""
)
clean_graph.set_entry_point("CLEAN")
clean_graph.set_finish_point("CLEAN")
# Out:
# Added AI node: CLEAN (model: gpt-4.1-nano)
# Set entry point: CLEAN
# Set finish point: CLEAN

# %%
extract_graph = EuriaiLangGraph(api_key=EURI_API_KEY, default_model=MODEL)
extract_graph.add_ai_node(
    "EXTRACT",
    """From CLEAN_TEXT, return STRICT JSON with keys exactly:
vendor, number, date, total, currency,
line_items (list of {{description, quantity, unit_price, amount}}).

Unknown → null. Numbers numeric. Dates YYYY-MM-DD if possible.
JSON ONLY, no extra text.

CLEAN_TEXT:
{clean_text}"""
)
extract_graph.set_entry_point("EXTRACT")
extract_graph.set_finish_point("EXTRACT")
# Out:
# Added AI node: EXTRACT (model: gpt-4.1-nano)
# Set entry point: EXTRACT
# Set finish point: EXTRACT

# %%
def pick_text(x, *, prefer_key=None):
    """Return a plain string from various possible structures.
    If x is a dict, try prefer_key or common keys; else stringify.
    """
    if isinstance(x, str):
        return x
    if isinstance(x, dict):
        if prefer_key and prefer_key in x and isinstance(x[prefer_key], str):
            return x[prefer_key]
        for k in ("output", "text", "CLEAN_output", "EXTRACT_output"):
            if k in x and isinstance(x[k], str):
                return x[k]
        return json.dumps(x, ensure_ascii=False)
    return str(x)

# %%
def parse_json_safe(raw):
    """Parse JSON robustly. Accepts dict or str; falls back to substring."""
    if isinstance(raw, dict):
        return raw
    if not isinstance(raw, str):
        return {"__raw__": raw}
    try:
        return json.loads(raw)
    except Exception:
        pass
    try:
        s, e = raw.find("{"), raw.rfind("}")
        if s != -1 and e != -1 and e > s:
            return json.loads(raw[s:e+1])
    except Exception:
        pass
    return {"__raw__": raw}

# %%
def _heuristic_extract(clean_text: str) -> dict:
    """Very simple regex-based extractor to keep DB flowing when AI is down."""
    def find(pat, s):
        m = re.search(pat, s, re.IGNORECASE)
        return m.group(1).strip() if m else None

    vendor = find(r"Vendor:\s*(.+)", clean_text)
    number = find(r"(?:Invoice Number|Invoice No\.?):\s*([A-Za-z0-9\-]+)", clean_text)
    date   = find(r"(?:Invoice Date|Date):\s*([0-9]{4}-[0-9]{2}-[0-9]{2})", clean_text)
    total  = find(r"Total:\s*([0-9]+(?:\.[0-9]+)?)", clean_text)
    curr   = find(r"Total:\s*[0-9]+(?:\.[0-9]+)?\s*([A-Za-z]{3})", clean_text) or find(r"Currency:\s*([A-Za-z]{3})", clean_text)

    try: total = float(total) if total is not None else None
    except: total = None

    return {
        "vendor": vendor,
        "number": number,
        "date":   date,
        "total":  total,
        "currency": curr,
        "line_items": []
    }

# %%
def NODE_OCR(file_path: str) -> Dict[str, Any]:
    """Read an image or PDF file and return OCR text."""
    file_ext = os.path.splitext(file_path)[1].lower()
    
    if file_ext in [".png", ".jpg", ".jpeg"]:
        # Existing image OCR logic
        text = "\n".join(ocr.readtext(file_path, detail=0))
        return {"ocr_text": text}
    
    elif file_ext == ".pdf":
        # PDF processing logic
        doc = fitz.open(file_path)
        full_text = []
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            # First, try to extract text directly
            page_text = page.get_text()
            if page_text.strip():
                full_text.append(page_text)
            else:
                # If no text, assume it's an image-based PDF and use OCR
                pix = page.get_pixmap()
                img_bytes = pix.tobytes("png")
                # Use easyocr on the image bytes
                ocr_results = ocr.readtext(img_bytes, detail=0)
                full_text.append("\n".join(ocr_results))
        
        doc.close()
        return {"ocr_text": "\n".join(full_text)}
        
    else:
        # Unsupported file type
        warnings.warn(f"Unsupported file type: {file_ext}")
        return {"ocr_text": ""}

# %%
a = NODE_OCR('content.pdf')

# %%
with open('output.txt', 'w', encoding='utf-8') as f:
    for i in a['ocr_text'].split('\n'):
        print(i)
        f.write(i + '\n')
# Out:
# 7M
# MHz Crystal
# Rev. 1.09
# Page 1
# www.txccrystal.com
# 16 ~ 20  MHz
# 60Ω  Max.
# 20 ~ 64  MHz
# 50Ω  Max.
# 80Ω  Max.
# 12 ~ 16  MHz
# 80Ω  Max.
# 80 ~ 114  MHz
# 60Ω  Max.
# 10 ~ 12  MHz
# 150Ω  Max.
# 60 ~ 80  MHz
# Notes:
# [1] Please contact us for low aging +/-1ppm grade crystals.
# Motional Resistance (ESR)
# Fundamental
# 3rd Overtone
# Aging (at 25°C ± 3°C, first year)
# Faging
#  ±3ppm Max.
# Note [1]
# Storage Temperature Range
# TSTR
# -40°C ~ +85°C
# Drive Level
# DL
# 1 ~ 200μW (100μW Typ.)
# Load Capacitance
# CL
# 6pF, 7pF, 8pF, 9pF, 10pF
# 12pF, 16pF, 18pF, 20pF
# -40°C ~ +85°C
# -40°C ~ +125°C
# Shunt Capacitance
# C0
# 3pF Max.
# -40°C ~ +85°C
# ±20 ppm
# ±15 ppm
# ±60 ppm
# -40°C ~ +125°C
# Operating Temperature Range
# TOTR
# -20°C ~ +70°C
# Frequency Stability over
# Operating Temperature Range
# (refer to 25°C)
# Fstab
# ±30 ppm
# -20°C ~ +70°C
# ±20 ppm
# ±10 ppm
# ±10 ppm
# -30°C ~ +85°C
# ±30 ppm
# Frequency Tolerance
# Ftol
# ±30ppm, ±20ppm, ±10ppm
# at 25°C
# Electrical Characteristics
# Item
# 7M
# Conditions
# Frequency Range
# F0
# 10MHz ~ 114MHz
#
# RoHS compliant & Pb free
#
# External dimensions (mm)
#
# Computer peripherals
# L : 3.2 x W : 2.5 x H : 0.7
#
# Consumer products
#
# Ceramic SMD package
#
# Cellular phone, Pager, DSC
#
# Seam sealing
#
# Display, TV
# Features
# Applications
#
# Frequency range : 10MHz to 114MHz
#
# Bluetooth, Wireless LAN
#
# 7M
# MHz Crystal
# Rev. 1.09
# Page 2
# www.txccrystal.com
# -
# T
# 7M
# -
# 20.000M A H E
# Dimensions
# Ordering Information
# Frequency Tolerance (at 25°C)
# A
# ± 30 ppm
# D
# ± 20 ppm
# E
# ± 10 ppm
# Frequency Stability (over Temp.)
# A
# ± 30 ppm  ( -20°C ~ +70°C )
# D
# ± 20 ppm  ( -20°C ~ +70°C )
# E
# ± 10 ppm  ( -20°C ~ +70°C )
# T
# ± 10 ppm  ( -30°C ~ +85°C )
# H
# ± 30 ppm  ( -40°C ~ +85°C )
# I
# ± 20 ppm  ( -40°C ~ +85°C )
# J
# ± 15 ppm  ( -40°C ~ +85°C )
# K
# ± 60 ppm  ( -40°C ~ +125°C )
# Load Capacitance
# B
# 6 pF
# Y
# 7 pF
# V
# 8 pF
# C
# 9 pF
# Q
# 10 pF
# E
# 12 pF
# I
# 16 pF
# J
# 18 pF
# K
# 20 pF
# Packaging Method
# T
# Tape & Reel
# Frequency in Hz
# Please contact us for
# available frequencies
#
# 7M
# MHz Crystal
# Rev. 1.09
# Page 3
# www.txccrystal.com
# Packing
# Reflow Profile
# (°C)
# 260
# 220
# 150
# 180
# Time (sec)
# 120 sec
# 60 sec
# 10 sec
# Solder melting point : 220°C ± 10°C, 60 sec. Min.
# Peak temperature : 260°C ± 10°C, 10 sec. Min.
# (Unit: mm)
# (Unit: mm)
#
# Mouser Electronics
#
# Authorized Distributor
#
#
# Click to View Pricing, Inventory, Delivery & Lifecycle Information:
#
#
#
#
# TXC Corporation:
#
#
#   7M-12.000MAAJ-T  7M-12.288MAAJ-T  7M-13.000MAAJ-T  7M-13.560MAAJ-T  7M-14.31818MAAJ-T  7M-
# 16.000MAAJ-T  7M-16.384MAAJ-T  7M-16.9344MAAJ-T  7M-18.432MAAJ-T  7M-19.200MAAJ-T  7M-20.000MAAJ-T
# 7M-24.000MAAJ-T  7M-24.576MAAJ-T  7M-25.000MAAJ-T  7M-26.000MAAJ-T  7M-27.000MAAJ-T  7M-27.120MAAJ-T
#   7M-30.000MAAJ-T  7M-32.000MAAJ-T  7M-36.000MAAJ-T  7M-38.400MAAJ-T  7M-40.000MAAJ-T  7M-48.000MAAJ-
# T  7M-10.000MAAJ-T  7M-50.000MAAJ-T  7M-36.000MAHV-T  7M-16.000MAHV-T  7M-24.000MAHV-T  7M-
# 10.000MAHV-T  7M-13.000MAHV-T  7M-32.000MAHV-T  7M-38.400MAHV-T  7M-50.000MAHV-T  7M-26.000MAKV-T
# 7M-26.000MAHV-T  7M-27.120MAHV-T  7M-19.200MAHV-T  7M-25.000MAKV-T  7M-27.000MAKV-T  7M-
# 37.400MAHV-T  7M-25.000MAHV-T  7M-40.000MAKV-T  7M-40.000MAHV-T  7M-27.000MAHV-T  7M-24.000MAKV-T
# 7M-20.000MAHV-T  7M-12.288MAHV-T  7M-30.000MAHV-T  7M-48.000MAHV-T  7M-12.000MAHV-T  7M25070033
# 7M26000028  7M20020003  7M25000196  7M24070019  7M24085001  7M24000218  7M25030004  7M12270003
# 7M25000055  7M26070013  7M40000129  7M40000002  7M27000050  7M25070010  7M12000048  7M25000080
# 7M40000009  7M25070060  7M25000003  7M25070018  7M16000099  7M25000013  7M25070025  7M48020003
# 7M12070021  7M48000003  7M25000019  7M27100001  7M12070015  7M25070063  7M31270003  7M32030001
# 7M50070014  7M24070016  7M12070005  7M12020002  7M38400010  7M24000174  7M25000018  7M24000138
# 7M18470004  7M25000041  7M25000016  7M48070001  7M24077005  7M25070006  7M16090001  7M12000039
# 7M27170001

# %%
b = NODE_CLEAN(a)
# Out:
# [values] {'ocr_text': {'ocr_text': '7M\nMHz Crystal \nRev. 1.09\nPage 1\nwww.txccrystal.com\n16 ~ 20  MHz\n60Ω  Max.\n20 ~ 64  MHz\n50Ω  Max.\n80Ω  Max.\n12 ~ 16  MHz\n80Ω  Max.\n80 ~ 114  MHz\n60Ω  Max.\n10 ~ 12  MHz\n150Ω  Max.\n60 ~ 80  MHz\nNotes:\n[1] Please contact us for low aging +/-1ppm grade crystals.\nMotional Resistance (ESR)\nFundamental\n3rd Overtone\nAging (at 25°C ± 3°C, first year)\nFaging\n ±3ppm Max.\nNote [1]\nStorage Temperature Range\nTSTR\n-40°C ~ +85°C\nDrive Level\nDL\n1 ~ 200μW (100μW Typ.)\nLoad Capacitance\nCL\n6pF, 7pF, 8pF, 9pF, 10pF\n12pF, 16pF, 18pF, 20pF\n-40°C ~ +85°C\n-40°C ~ +125°C\nShunt Capacitance\nC0\n3pF Max.\n-40°C ~ +85°C\n±20 ppm\n±15 ppm\n±60 ppm\n-40°C ~ +125°C\nOperating Temperature Range\nTOTR\n-20°C ~ +70°C\nFrequency Stability over\nOperating Temperature Range\n(refer to 25°C)\nFstab\n±30 ppm\n-20°C ~ +70°C\n±20 ppm\n±10 ppm\n±10 ppm\n-30°C ~ +85°C\n±30 ppm\nFrequency Tolerance\nFtol\n±30ppm, ±20ppm, ±10ppm\nat 25°C\nElectrical Characteristics\nItem\n7M\nConditions\nFrequency Range\nF0\n10MHz ~ 114MHz\n\x1f\nRoHS compliant & Pb free\n\x1f\nExternal dimensions (mm)\n\x1f\nComputer peripherals\nL : 3.2 x W : 2.5 x H : 0.7\n\x1f\nConsumer products\n\x1f\nCeramic SMD package\n\x1f\nCellular phone, Pager, DSC\n\x1f\nSeam sealing\n\x1f\nDisplay, TV\nFeatures\nApplications\n\x1f\nFrequency range : 10MHz to 114MHz\n\x1f\nBluetooth, Wireless LAN\n\n7M\nMHz Crystal \nRev. 1.09\nPage 2\nwww.txccrystal.com\n-\nT\n7M\n-\n20.000M A H E\nDimensions\nOrdering Information\nFrequency Tolerance (at 25°C)\nA\n± 30 ppm\nD\n± 20 ppm\nE\n± 10 ppm\nFrequency Stability (over Temp.)\nA\n± 30 ppm  ( -20°C ~ +70°C )\nD\n± 20 ppm  ( -20°C ~ +70°C )\nE\n± 10 ppm  ( -20°C ~ +70°C )\nT\n± 10 ppm  ( -30°C ~ +85°C )\nH\n± 30 ppm  ( -40°C ~ +85°C )\nI\n± 20 ppm  ( -40°C ~ +85°C )\nJ\n± 15 ppm  ( -40°C ~ +85°C )\nK\n± 60 ppm  ( -40°C ~ +125°C )\nLoad Capacitance\nB\n6 pF\nY\n7 pF\nV\n8 pF\nC\n9 pF\nQ\n10 pF\nE\n12 pF\nI\n16 pF\nJ\n18 pF\nK\n20 pF\nPackaging Method\nT\nTape & Reel\nFrequency in Hz\nPlease contact us for \navailable frequencies\n\n7M\nMHz Crystal \nRev. 1.09\nPage 3\nwww.txccrystal.com\nPacking\nReflow Profile\n(°C)\n260\n220\n150\n180\nTime (sec)\n120 sec\n60 sec\n10 sec\nSolder melting point : 220°C ± 10°C, 60 sec. Min.\nPeak temperature : 260°C ± 10°C, 10 sec. Min.\n(Unit: mm)\n(Unit: mm)\n\nMouser Electronics\n  \nAuthorized Distributor\n \n  \nClick to View Pricing, Inventory, Delivery & Lifecycle Information:\n \n \n \n \nTXC Corporation:\n  \n \n  7M-12.000MAAJ-T  7M-12.288MAAJ-T  7M-13.000MAAJ-T  7M-13.560MAAJ-T  7M-14.31818MAAJ-T  7M-\n16.000MAAJ-T  7M-16.384MAAJ-T  7M-16.9344MAAJ-T  7M-18.432MAAJ-T  7M-19.200MAAJ-T  7M-20.000MAAJ-T \n7M-24.000MAAJ-T  7M-24.576MAAJ-T
\nat 25°C\nElectrical Characteristics\nItem\n7M\nConditions\nFrequency Range\nF0\n10MHz ~ 114MHz\n\x1f\nRoHS compliant & Pb free\n\x1f\nExternal dimensions (mm)\n\x1f\nComputer peripherals\nL : 3.2 x W : 2.5 x H : 0.7\n\x1f\nConsumer products\n\x1f\nCeramic SMD package\n\x1f\nCellular phone, Pager, DSC\n\x1f\nSeam sealing\n\x1f\nDisplay, TV\nFeatures\nApplications\n\x1f\nFrequency range : 10MHz to 114MHz\n\x1f\nBluetooth, Wireless LAN\n\n7M\nMHz Crystal \nRev. 1.09\nPage 2\nwww.txccrystal.com\n-\nT\n7M\n-\n20.000M A H E\nDimensions\nOrdering Information\nFrequency Tolerance (at 25°C)\nA\n± 30 ppm\nD\n± 20 ppm\nE\n± 10 ppm\nFrequency Stability (over Temp.)\nA\n± 30 ppm  ( -20°C ~ +70°C )\nD\n± 20 ppm  ( -20°C ~ +70°C )\nE\n± 10 ppm  ( -20°C ~ +70°C )\nT\n± 10 ppm  ( -30°C ~ +85°C )\nH\n± 30 ppm  ( -40°C ~ +85°C )\nI\n± 20 ppm  ( -40°C ~ +85°C )\nJ\n± 15 ppm  ( -40°C ~ +85°C )\nK\n± 60 ppm  ( -40°C ~ +125°C )\nLoad Capacitance\nB\n6 pF\nY\n7 pF\nV\n8 pF\nC\n9 pF\nQ\n10 pF\nE\n12 pF\nI\n16 pF\nJ\n18 pF\nK\n20 pF\nPackaging Method\nT\nTape & Reel\nFrequency in Hz\nPlease contact us for \navailable frequencies\n\n7M\nMHz Crystal \nRev. 1.09\nPage 3\nwww.txccrystal.com\nPacking\nReflow Profile\n(°C)\n260\n220\n150\n180\nTime (sec)\n120 sec\n60 sec\n10 sec\nSolder melting point : 220°C ± 10°C, 60 sec. Min.\nPeak temperature : 260°C ± 10°C, 10 sec. Min.\n(Unit: mm)\n(Unit: mm)\n\nMouser Electronics\n  \nAuthorized Distributor\n \n  \nClick to View Pricing, Inventory, Delivery & Lifecycle Information:\n \n \n \n \nTXC Corporation:\n  \n \n  7M-12.000MAAJ-T  7M-12.288MAAJ-T  7M-13.000MAAJ-T  7M-13.560MAAJ-T  7M-14.31818MAAJ-T  7M-\n16.000MAAJ-T  7M-16.384MAAJ-T  7M-16.9344MAAJ-T  7M-18.432MAAJ-T  7M-19.200MAAJ-T  7M-20.000MAAJ-T \n7M-24.000MAAJ-T  7M-24.576MAAJ-T  7M-25.000MAAJ-T  7M-26.000MAAJ-T  7M-27.000MAAJ-T  7M-27.120MAAJ-T\n  7M-30.000MAAJ-T  7M-32.000MAAJ-T  7M-36.000MAAJ-T  7M-38.400MAAJ-T  7M-40.000MAAJ-T  7M-48.000MAAJ-\nT  7M-10.000MAAJ-T  7M-50.000MAAJ-T  7M-36.000MAHV-T  7M-16.000MAHV-T  7M-24.000MAHV-T  7M-\n10.000MAHV-T  7M-13.000MAHV-T  7M-32.000MAHV-T  7M-38.400MAHV-T  7M-50.000MAHV-T  7M-26.000MAKV-T \n7M-26.000MAHV-T  7M-27.120MAHV-T  7M-19.200MAHV-T  7M-25.000MAKV-T  7M-27.000MAKV-T  7M-\n37.400MAHV-T  7M-25.000MAHV-T  7M-40.000MAKV-T  7M-40.000MAHV-T  7M-27.000MAHV-T  7M-24.000MAKV-T \n7M-20.000MAHV-T  7M-12.288MAHV-T  7M-30.000MAHV-T  7M-48.000MAHV-T  7M-12.000MAHV-T  7M25070033 \n7M26000028  7M20020003  7M25000196  7M24070019  7M24085001  7M24000218  7M25030004  7M12270003 \n7M25000055  7M26070013  7M40000129  7M40000002  7M27000050  7M25070010  7M12000048  7M25000080 \n7M40000009  7M25070060  7M25000003  7M25070018  7M16000099  7M25000013  7M25070025  7M48020003 \n7M12070021  7M48000003  7M25000019  7M27100001  7M12070015  7M25070063  7M31270003  7M32030001 \n7M50070014  7M24070016  7M12070005  7M12020002  7M38400010  7M24000174  7M25000018  7M24000138 \n7M18470004  7M25000041  7M25000016  7M48070001  7M24077005  7M25070006  7M16090001  7M12000039 \n ...
# [values] {'ocr_text': {'ocr_text': '7M\nMHz Crystal \nRev. 1.09\nPage 1\nwww.txccrystal.com\n16 ~ 20  MHz\n60Ω  Max.\n20 ~ 64  MHz\n50Ω  Max.\n80Ω  Max.\n12 ~ 16  MHz\n80Ω  Max.\n80 ~ 114  MHz\n60Ω  Max.\n10 ~ 12  MHz\n150Ω  Max.\n60 ~ 80  MHz\nNotes:\n[1] Please contact us for low aging +/-1ppm grade crystals.\nMotional Resistance (ESR)\nFundamental\n3rd Overtone\nAging (at 25°C ± 3°C, first year)\nFaging\n ±3ppm Max.\nNote [1]\nStorage Temperature Range\nTSTR\n-40°C ~ +85°C\nDrive Level\nDL\n1 ~ 200μW (100μW Typ.)\nLoad Capacitance\nCL\n6pF, 7pF, 8pF, 9pF, 10pF\n12pF, 16pF, 18pF, 20pF\n-40°C ~ +85°C\n-40°C ~ +125°C\nShunt Capacitance\nC0\n3pF Max.\n-40°C ~ +85°C\n±20 ppm\n±15 ppm\n±60 ppm\n-40°C ~ +125°C\nOperating Temperature Range\nTOTR\n-20°C ~ +70°C\nFrequency Stability over\nOperating Temperature Range\n(refer to 25°C)\nFstab\n±30 ppm\n-20°C ~ +70°C\n±20 ppm\n±10 ppm\n±10 ppm\n-30°C ~ +85°C\n±30 ppm\nFrequency Tolerance\nFtol\n±30ppm, ±20ppm, ±10ppm\nat 25°C\nElectrical Characteristics\nItem\n7M\nConditions\nFrequency Range\nF0\n10MHz ~ 114MHz\n\x1f\nRoHS compliant & Pb free\n\x1f\nExternal dimensions (mm)\n\x1f\nComputer peripherals\nL : 3.2 x W : 2.5 x H : 0.7\n\x1f\nConsumer products\n\x1f\nCeramic SMD package\n\x1f\nCellular phone, Pager, DSC\n\x1f\nSeam sealing\n\x1f\nDisplay, TV\nFeatures\nApplications\n\x1f\nFrequency range : 10MHz to 114MHz\n\x1f\nBluetooth, Wireless LAN\n\n7M\nMHz Crystal \nRev. 1.09\nPage 2\nwww.txccrystal.com\
7M40000009  7M25070060  7M25000003  7M25070018  7M16000099  7M25000013  7M25070025  7M48020003 \n7M12070021  7M48000003  7M25000019  7M27100001  7M12070015  7M25070063  7M31270003  7M32030001 \n7M50070014  7M24070016  7M12070005  7M12020002  7M38400010  7M24000174  7M25000018  7M24000138 \n7M18470004  7M25000041  7M25000016  7M48070001  7M24077005  7M25070006  7M16090001  7M12000039 \n7M27170001\ ...
# Workflow completed in 7.07s

# %%
c = NODE_EXTRACT(b)
# Out:
# Graph compiled successfully
# [values] {'clean_text': '{"clean_text": "Cleaned and Fact-Checked Plain Text Version:\\n\\n---\\n\\n**Product: 7M MHz Crystal Rev. 1.09**  \\nWebsite: www.txccrystal.com\\n\\n**Frequency Range:** 10 MHz to 114 MHz\\n\\n**Electrical Characteristics:**\\n\\n| Item                        | Conditions                                | Details                                              |\\n|------------------------------|-------------------------------------------|------------------------------------------------------|\\n| Frequency Range (F0)         | -                                         | 10 MHz to 114 MHz                                   |\\n| RoHS Compliance              | -                                         | RoHS compliant & Pb free                            |\\n| External Dimensions (mm)     | -                                         | Length: 3.2 mm, Width: 2.5 mm, Height: 0.7 mm       |\\n| Applications                 | -                                         | Computer peripherals, Consumer products, Cellular phone, Pager, DSC, Display, TV |\\n| Frequency Range              | -                                         | 10 MHz to 114 MHz                                   |\\n\\n---\\n\\n**Frequency Tolerance (at 25°C):**\\n\\n| Code | Tolerance | Temperature Range                   |\\n|--------|--------------|-------------------------------------|\\n| A      | ±30 ppm     | -20°C ~ +70°C                      |\\n| D      | ±20 ppm     | -20°C ~ +70°C                      |\\n| E      | ±10 ppm     | -20°C ~ +70°C                      |\\n\\n**Frequency Stability over Temperature Range:**\\n\\n| Code | Stability | Temperature Range                   |\\n|--------|--------------|-------------------------------------|\\n| A      | ±30 ppm     | -20°C ~ +70°C                      |\\n| D      | ±20 ppm     | -20°C ~ +70°C                      |\\n| E      | ±10 ppm     | -20°C ~ +70°C                      |\\n| T      | ±10 ppm     | -30°C ~ +85°C                      |\\n| H      | ±30 ppm     | -40°C ~ +85°C                      |\\n| I      | ±20 ppm     | -40°C ~ +85°C                      |\\n| J      | ±15 ppm     | -40°C ~ +85°C                      |\\n| K      | ±60 ppm     | -40°C ~ +125°C                     |\\n\\n---\\n\\n**Frequency Stability (over Temp):**  \\nRefer to 25°C stability data above.\\n\\n**Frequency Tolerance (Ftol):**\\n\\n| Tolerance | Value at 25°C |\\n|--------------|----------------|\\n| ±30 ppm     | Code: N/A (see above) |\\n| ±20 ppm     | -                          |\\n| ±10 ppm     | -                          |\\n\\n**Drive Level (DL):** 1 to 200 μW (typical 100 μW)  \\n**Load Capacitance (CL):** 6 pF, 7 pF, 8 pF, 9 pF, 10 pF, 12 pF, 16 pF, 18 pF, 20 pF  \\n**Shunt Capacitance (C0):** Max 3 pF  \\n**Storage Temperature Range (TSTR):** -40°C to +85°C (standard), -40°C to +125°C (extended)  \\n**Operating Temperature Range (TOTR):** -20°C to +70°C\\n\\n---\\n\\n**Notes:**\\n\\n- Please contact us for low aging (+/-1 ppm) grade crystals.\\n- Max motional resistance (ESR) varies with frequency:\\n  - 7 MHz to 12 MHz: Max 80Ω\\n  - 12 MHz to 16 MHz: Max 80Ω\\n  - 16 MHz to 20 MHz: Max 60Ω\\n  - 20 MHz to 64 MHz: Max 50Ω\\n  - 80 MHz to 114 MHz: Max 60Ω\\n  - 10 MHz to 12 MHz: Max 150Ω\\n\\n---\\n\\n**Packaging and Soldering:**\\n\\n- Packaging Method: Tape & Reel\\n- Reflow Solder Profile:\\n  - Peak temperature: 260°C ± 10°C for at least 10 seconds\\n  - Solder melting point: 220°C ± 10°C for at least 60 seconds\\n\\n---\\n\\n**Ordering Information (Frequency in Hz):**\\n\\n| Code | Frequency Tolerance | Stability | Load Capacitance | Notes |\\n|--------|------------------------|--------------|-------------------|-------|\\n| A      | ±30 ppm               | ±30 ppm     | 6 pF             | -     |\\n| D      | ±20 ppm               | ±20 ppm     | 7 pF             | -     |\\n| E      | ±10 ppm               | ±10 ppm     | 9 pF             | -     |\\n| T      | ±10 ppm  ...
# [updates] {'EXTRACT': {'clean_text': '{"clean_text": "Cleaned and Fact-Checked Plain Text Version:\\n\\n---\\n\\n**Product: 7M MHz Crystal Rev. 1.09**  \\nWebsite: www.txccrystal.com\\n\\n**Frequency Range:** 10 MHz to 114 MHz\\n\\n**Electrical Characteristics:**\\n\\n| Item                        | Conditions                                | Details                                              |\\n|------------------------------|-------------------------------------------|------------------------------------------------------|\\n| Frequency Range (F0)         | -                                         | 10 MHz to 114 MHz                                   |\\n| RoHS Compliance              | -                                         | RoHS compliant & Pb free                            |\\n| External Dimensions (mm)     | -                                         | Length: 3.2 mm, Width: 2.5 mm, Height: 0.7 mm       |\\n| Applications                 | -                                         | Computer peripherals, Consumer products, Cellular phone, Pager, DSC, Display, TV |\\n| Frequency Range              | -                                         | 10 MHz to 114 MHz                                   |\\n\\n---\\n\\n**Frequency Tolerance (at 25°C):**\\n\\n| Code | Tolerance | Temperature Range                   |\\n|--------|--------------|-------------------------------------|\\n| A      | ±30 ppm     | -20°C ~ +70°C                      |\\n| D      | ±20 ppm     | -20°C ~ +70°C                      |\\n| E      | ±10 ppm     | -20°C ~ +70°C                      |\\n\\n**Frequency Stability over Temperature Range:**\\n\\n| Code | Stability | Temperature Range                   |\\n|--------|--------------|-------------------------------------|\\n| A      | ±30 ppm     | -20°C ~ +70°C                      |\\n| D      | ±20 ppm     | -20°C ~ +70°C                      |\\n| E      | ±10 ppm     | -20°C ~ +70°C                      |\\n| T      | ±10 ppm     | -30°C ~ +85°C                      |\\n| H      | ±30 ppm     | -40°C ~ +85°C                      |\\n| I      | ±20 ppm     | -40°C ~ +85°C                      |\\n| J      | ±15 ppm     | -40°C ~ +85°C                      |\\n| K      | ±60 ppm     | -40°C ~ +125°C                     |\\n\\n---\\n\\n**Frequency Stability (over Temp):**  \\nRefer to 25°C stability data above.\\n\\n**Frequency Tolerance (Ftol):**\\n\\n| Tolerance | Value at 25°C |\\n|--------------|----------------|\\n| ±30 ppm     | Code: N/A (see above) |\\n| ±20 ppm     | -                          |\\n| ±10 ppm     | -                          |\\n\\n**Drive Level (DL):** 1 to 200 μW (typical 100 μW)  \\n**Load Capacitance (CL):** 6 pF, 7 pF, 8 pF, 9 pF, 10 pF, 12 pF, 16 pF, 18 pF, 20 pF  \\n**Shunt Capacitance (C0):** Max 3 pF  \\n**Storage Temperature Range (TSTR):** -40°C to +85°C (standard), -40°C to +125°C (extended)  \\n**Operating Temperature Range (TOTR):** -20°C to +70°C\\n\\n---\\n\\n**Notes:**\\n\\n- Please contact us for low aging (+/-1 ppm) grade crystals.\\n- Max motional resistance (ESR) varies with frequency:\\n  - 7 MHz to 12 MHz: Max 80Ω\\n  - 12 MHz to 16 MHz: Max 80Ω\\n  - 16 MHz to 20 MHz: Max 60Ω\\n  - 20 MHz to 64 MHz: Max 50Ω\\n  - 80 MHz to 114 MHz: Max 60Ω\\n  - 10 MHz to 12 MHz: Max 150Ω\\n\\n---\\n\\n**Packaging and Soldering:**\\n\\n- Packaging Method: Tape & Reel\\n- Reflow Solder Profile:\\n  - Peak temperature: 260°C ± 10°C for at least 10 seconds\\n  - Solder melting point: 220°C ± 10°C for at least 60 seconds\\n\\n---\\n\\n**Ordering Information (Frequency in Hz):**\\n\\n| Code | Frequency Tolerance | Stability | Load Capacitance | Notes |\\n|--------|------------------------|--------------|-------------------|-------|\\n| A      | ±30 ppm               | ±30 ppm     | 6 pF             | -     |\\n| D      | ±20 ppm               | ±20 ppm     | 7 pF             | -     |\\n| E      | ±10 ppm               | ±10 ppm     | 9 pF             | -     |\\n| T    ...
# [values] {'clean_text': '{"clean_text": "Cleaned and Fact-Checked Plain Text Version:\\n\\n---\\n\\n**Product: 7M MHz Crystal Rev. 1.09**  \\nWebsite: www.txccrystal.com\\n\\n**Frequency Range:** 10 MHz to 114 MHz\\n\\n**Electrical Characteristics:**\\n\\n| Item                        | Conditions                                | Details                                              |\\n|------------------------------|-------------------------------------------|------------------------------------------------------|\\n| Frequency Range (F0)         | -                                         | 10 MHz to 114 MHz                                   |\\n| RoHS Compliance              | -                                         | RoHS compliant & Pb free                            |\\n| External Dimensions (mm)     | -                                         | Length: 3.2 mm, Width: 2.5 mm, Height: 0.7 mm       |\\n| Applications                 | -                                         | Computer peripherals, Consumer products, Cellular phone, Pager, DSC, Display, TV |\\n| Frequency Range              | -                                         | 10 MHz to 114 MHz                                   |\\n\\n---\\n\\n**Frequency Tolerance (at 25°C):**\\n\\n| Code | Tolerance | Temperature Range                   |\\n|--------|--------------|-------------------------------------|\\n| A      | ±30 ppm     | -20°C ~ +70°C                      |\\n| D      | ±20 ppm     | -20°C ~ +70°C                      |\\n| E      | ±10 ppm     | -20°C ~ +70°C                      |\\n\\n**Frequency Stability over Temperature Range:**\\n\\n| Code | Stability | Temperature Range                   |\\n|--------|--------------|-------------------------------------|\\n| A      | ±30 ppm     | -20°C ~ +70°C                      |\\n| D      | ±20 ppm     | -20°C ~ +70°C                      |\\n| E      | ±10 ppm     | -20°C ~ +70°C                      |\\n| T      | ±10 ppm     | -30°C ~ +85°C                      |\\n| H      | ±30 ppm     | -40°C ~ +85°C                      |\\n| I      | ±20 ppm     | -40°C ~ +85°C                      |\\n| J      | ±15 ppm     | -40°C ~ +85°C                      |\\n| K      | ±60 ppm     | -40°C ~ +125°C                     |\\n\\n---\\n\\n**Frequency Stability (over Temp):**  \\nRefer to 25°C stability data above.\\n\\n**Frequency Tolerance (Ftol):**\\n\\n| Tolerance | Value at 25°C |\\n|--------------|----------------|\\n| ±30 ppm     | Code: N/A (see above) |\\n| ±20 ppm     | -                          |\\n| ±10 ppm     | -                          |\\n\\n**Drive Level (DL):** 1 to 200 μW (typical 100 μW)  \\n**Load Capacitance (CL):** 6 pF, 7 pF, 8 pF, 9 pF, 10 pF, 12 pF, 16 pF, 18 pF, 20 pF  \\n**Shunt Capacitance (C0):** Max 3 pF  \\n**Storage Temperature Range (TSTR):** -40°C to +85°C (standard), -40°C to +125°C (extended)  \\n**Operating Temperature Range (TOTR):** -20°C to +70°C\\n\\n---\\n\\n**Notes:**\\n\\n- Please contact us for low aging (+/-1 ppm) grade crystals.\\n- Max motional resistance (ESR) varies with frequency:\\n  - 7 MHz to 12 MHz: Max 80Ω\\n  - 12 MHz to 16 MHz: Max 80Ω\\n  - 16 MHz to 20 MHz: Max 60Ω\\n  - 20 MHz to 64 MHz: Max 50Ω\\n  - 80 MHz to 114 MHz: Max 60Ω\\n  - 10 MHz to 12 MHz: Max 150Ω\\n\\n---\\n\\n**Packaging and Soldering:**\\n\\n- Packaging Method: Tape & Reel\\n- Reflow Solder Profile:\\n  - Peak temperature: 260°C ± 10°C for at least 10 seconds\\n  - Solder melting point: 220°C ± 10°C for at least 60 seconds\\n\\n---\\n\\n**Ordering Information (Frequency in Hz):**\\n\\n| Code | Frequency Tolerance | Stability | Load Capacitance | Notes |\\n|--------|------------------------|--------------|-------------------|-------|\\n| A      | ±30 ppm               | ±30 ppm     | 6 pF             | -     |\\n| D      | ±20 ppm               | ±20 ppm     | 7 pF             | -     |\\n| E      | ±10 ppm               | ±10 ppm     | 9 pF             | -     |\\n| T      | ±10 ppm  ...
# Workflow completed in 2.79s
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def NODE_CLEAN(ocr_text: str) -> Dict[str, Any]:
    """Normalize noisy OCR text using the CLEAN AI node; fallback to pass-through on error."""
    try:
        clean_raw = clean_graph.run({"ocr_text": ocr_text})
        clean_text = pick_text(clean_raw, prefer_key="CLEAN_output")
        if not isinstance(clean_text, str) or not clean_text.strip():
            raise RuntimeError("Empty CLEAN output")
        return {"clean_text": clean_text, "CLEAN_raw": clean_raw}
    except Exception as e:
        print(f"[CLEAN:FALLBACK] {e}")
        return {"clean_text": ocr_text, "CLEAN_raw": {"fallback": True}}

# %%
def NODE_EXTRACT(clean_text_any) -> dict:
    """Extract structured JSON using the EXTRACT AI node; fallback to heuristic on error."""
    clean_text = pick_text(clean_text_any, prefer_key="CLEAN_output")
    try:
        result = extract_graph.run({"clean_text": clean_text})
        raw_json = pick_text(result, prefer_key="EXTRACT_output")
        return {"raw_json": raw_json, "EXTRACT_raw": result}
    except Exception as e:
        print(f"[EXTRACT:FALLBACK] {e}")
        heuristic = _heuristic_extract(clean_text)
        return {"raw_json": json.dumps(heuristic, ensure_ascii=False), "EXTRACT_raw": {"fallback": True}}

# %%
def NODE_VALIDATE(data: Dict[str, Any]) -> Dict[str, Any]:
    """Minimal schema checks and numeric sanity for demo purposes."""
    issues: List[str] = []
    for k in ["vendor", "number", "date", "currency"]:
        if k not in data or data.get(k) in (None, ""):
            issues.append(f"missing key: {k}")
    try:
        if data.get("total") is None:
            issues.append("total is null")
        else:
            float(data.get("total"))
    except Exception:
        issues.append(f"total not numeric: {data.get('total')}")
    if not isinstance(data.get("line_items", []), list):
        issues.append("line_items not a list")
    return {"valid": len(issues) == 0, "issues": issues}

# %%
def NODE_PERSIST(file_name: str, data: dict, raw_json_any):
    raw_json_str = json.dumps(raw_json_any, ensure_ascii=False) if not isinstance(raw_json_any, str) else raw_json_any
    con = sqlite3.connect(DB_PATH)
    cur = con.cursor()
    cur.execute(
        """
        INSERT INTO invoices(file_name, vendor, number, date, total, currency, raw_json)
        VALUES (?, ?, ?, ?, ?, ?, ?)
        """,
        (
            file_name,
            data.get("vendor"),
            data.get("number"),
            data.get("date"),
            data.get("total"),
            data.get("currency"),
            raw_json_str,
        ),
    )
    rowid = cur.lastrowid
    con.commit()
    con.close()
    print(f"[DB] Inserted row id={rowid} at {os.path.abspath(DB_PATH)}")
    return {"db": "sqlite", "rowid": rowid}

# %%
def NODE_NOTIFY(file_name: str, data: Dict[str, Any], valid: bool, issues: List[str]) -> None:
    status = "OK" if valid else f"WARN: {issues}"
    print(
        f"[{status}] file='{file_name}' vendor={data.get('vendor')} number={data.get('number')} total={data.get('total')} {data.get('currency')}"
    )

# %%
NODES = ["WATCH", "OCR", "CLEAN", "EXTRACT", "VALIDATE", "PERSIST", "NOTIFY"]
EDGES = [
    ("WATCH", "OCR"),
    ("OCR", "CLEAN"),
    ("CLEAN", "EXTRACT"),
    ("EXTRACT", "VALIDATE"),
    ("VALIDATE", "PERSIST"),
    ("PERSIST", "NOTIFY"),
]

# %%
def run_pipeline_for_file(file_path: str) -> None:
    file_name = os.path.basename(file_path)

    # OCR → CLEAN → EXTRACT
    ocr_out     = NODE_OCR(file_path)
    clean_out   = NODE_CLEAN(pick_text(ocr_out.get("ocr_text")))
    extract_out = NODE_EXTRACT(clean_out.get("clean_text"))

    # Parse JSON → VALIDATE
    raw_json = extract_out["raw_json"]
    data     = parse_json_safe(raw_json)
    val_out  = NODE_VALIDATE(data)

    # Persist + Notify
    NODE_PERSIST(file_name, data, raw_json)
    NODE_NOTIFY(file_name, data, val_out["valid"], val_out["issues"])

# %%
print(f"\nWatching '{INPUT_DIR}' every {POLL_SEC}s. Only NEW .png/.jpg/.pdf will be processed.")
try:
    while True:
        for fname in sorted(os.listdir(INPUT_DIR)):
            if not fname.lower().endswith((".png", ".jpg", ".jpeg", ".pdf")):
                continue
            if fname in seen:
                continue  # already processed (persists across restarts)
            fpath = os.path.join(INPUT_DIR, fname)
            try:
                run_pipeline_for_file(fpath)          # trigger full pipeline
                seen.add(fname); save_seen(seen)      # mark as processed
            except Exception as e:
                print(f"[ERROR] {fname}: {e}")
        time.sleep(POLL_SEC)
except KeyboardInterrupt:
    print("Stopped watching.")
# Out:
# Watching 'invoices' every 5s. Only NEW .png/.jpg/.pdf will be processed.
# d:\AppsRepository\invoice_generator\invoice-env\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Graph compiled successfully
# [values] {'ocr_text': '8\nL\'\n9\n\n130\n3\n8\n8\n3\n1\n6\n8\n8\n3\n63\n5\n1\n1\n1\n1\n1\n0\n23\n1\n1\n1\n1\n3\n1\n[\n1\n2\n9\n4\n1\n2\n8\n1\nL\n[\n2\nI\n{\n8\n1\n2\n8\nI\n{\n8\n2\nH\n5\nIV\n3\nJ\n\n3\n3\nE\n8\n1\n1\n2\n4\n3\n!\n8\n1\n4\n0\nNI \n9\n8\nWle\n2\n1\n6\nHplh\n8\n2\n7\n8\ng\nIlwh\ng ?\n[\n0\n0\n3\n8\ng\n2\nJ\n3\n8\n{\n1\n5\n1\n0\n1\n2\n8\n1\n0\n1\n8\nL\n#\n8\n2\n6\n1\n3\n8\n2l2g\n8\n1\n8\n0\n8\nO\no\n0\n5\n3\ng\n2\n7\nOBGYN VITALS MONITORING AND\n8 children\nNUTRITIONAL SCREENING FOR OUTPATIENTS\nVITALS MONITORING CHART\nNAME:\nAge:\n249k_\nUo $\nAtankyha\nmiSrq\nHeight:\nT62y\nQ@64<0)\nLMP:\nPatient:\nEDD:\nHusband:\nWEIGHT\nBMI\nNURSE\nBLOOD PRESSURE\nPULSE\nSPOz\nTEMP\nINITIALS\n(mmHg)\n(b/mts)\n(%)\n(*F)\n(Kg)\n(Kglm})\nI4ol &0\nGsbl\n9L6F\n64K4\n44/35\nEb4L\nJof:\n983/Azak\n94,3S\nL36L0\nR4bIK\n4LL\n9$2*E\nL4Lua\naLp-6\nLuiky EHwl\nHo\n@ckn\n3l4k\n44/a\n#8l4L\n0&f.\n927\nshlt-W\n#6/ ~\n9 9+\n91.5\n6p\n664K9\n35.30\nLR ,\n9900421492\nPage 1 of 2\nAWFTOBGIDOC/MR/OO5-00\nAster\nW<tEN4e\nPATIENT \nUHID\nBLOOD\nGROUP\nDATE\nHliy\nlwo \ntallle\n9la:\nEs6kt\n3vd\n8CHildren\nANTENATAL RECORD\nXWcll\nMu: Akaakla His)s\nUHID No:\n9ool6yboSAge/Gender:_24yle\nConsultant\'s Name:\nDs\nVizhaupaiy \nDate of Birth:\nMobile No;\nNo:\nEmergency Contact:\nIMPORTANT INFORMATION\nLMP\n8 ll2028 EDD\nIs/2\n20.26_Agreed EDD\nGroup:\nOccupation:\nAllergies:\nHusband/Partner\'s Name:\nOccupation:\nMarried For\nyears\nConsanguinity\nConception:\nPlanned\nUnplanned\nSpontaneous\nFertility Treatment\n
P:\nmmHg\nPR\nImin\nMiscarriage >12 weeks\nCaesarean\nCVS\nRS\nEctopic Pregnancies\nBirthweight <2.5 kg\nBreasts:\nMolar Pregnancies\nGestation under 37w\nThyroid:\nDate\nGA\nWeight\nBP\nUrine\nSFH\nOedema\nPallor\nPresentation\n(wks)\nP | G\n0\n(cm)\nNT\nsc#Juku\nlew\nmms\nDocuments\nMakw\nFhSIFhR\n[ns|\nUiloaded\nTT\nHigh risk factors\n2" Dose\nAction plan\n1"Dose\nAnti d\n28\nRemarks\nDoctor\'$ Sign with\nKMC\nLUOGEN-2\n20\n(iskfw\nFusl\nV0\nL1\nJulay\nL#eLC_XT\nLS~(\n#H\nT\n20,\ndtivusl\n00\n~1\nIL.\nZD\n(N\netak\nC2C\n04t\nO5TTdekyk\n4z\n~Bucuments Uploaded mn\nHISTZ_HFTy_\nFeg\nIDndM\nA45yeoflyok L\nWeeas\n# kmt9\nDate:\nMGDz\nIwly;', 'CLEAN_output': "Cleaned and Factually Preserved Text:\n\n---\n\n**GYN/OB VITALS MONITORING AND NUTRITIONAL SCREENING FOR OUTPATIENTS**  \n**VITALS MONITORING CHART**  \n\n**Patient Information:**  \n- Name: Atankyha  \n- Age: 24 years  \n- Height: 1.62 meters  \n- Weight: 64 kg  \n- BMI: 24.6  \n- LMP (Last Menstrual Period): 8 November 2028  \n- EDD (Estimated Date of Delivery): 20 June 2029  \n- Husband/Partner Name: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Occupation: Not specified  \n\n**Vital Signs:**  \n- Blood Pressure: 94/63 mmHg  \n- Pulse: 94 beats per minute  \n- SpO2 (Oxygen Saturation): Not specified  \n- Temperat ...
# [values] {'ocr_text': '8\nL\'\n9\n\n130\n3\n8\n8\n3\n1\n6\n8\n8\n3\n63\n5\n1\n1\n1\n1\n1\n0\n23\n1\n1\n1\n1\n3\n1\n[\n1\n2\n9\n4\n1\n2\n8\n1\nL\n[\n2\nI\n{\n8\n1\n2\n8\nI\n{\n8\n2\nH\n5\nIV\n3\nJ\n\n3\n3\nE\n8\n1\n1\n2\n4\n3\n!\n8\n1\n4\n0\nNI \n9\n8\nWle\n2\n1\n6\nHplh\n8\n2\n7\n8\ng\nIlwh\ng ?\n[\n0\n0\n3\n8\ng\n2\nJ\n3\n8\n{\n1\n5\n1\n0\n1\n2\n8\n1\n0\n1\n8\nL\n#\n8\n2\n6\n1\n3\n8\n2l2g\n8\n1\n8\n0\n8\nO\no\n0\n5\n3\ng\n2\n7\nOBGYN VITALS MONITORING AND\n8 children\nNUTRITIONAL SCREENING FOR OUTPATIENTS\nVITALS MONITORING CHART\nNAME:\nAge:\n249k_\nUo $\nAtankyha\nmiSrq\nHeight:\nT62y\nQ@64<0)\nLMP:\nPatient:\nEDD:\nHusband:\nWEIGHT\nBMI\nNURSE\nBLOOD PRESSURE\nPULSE\nSPOz\nTEMP\nINITIALS\n(mmHg)\n(b/mts)\n(%)\n(*F)\n(Kg)\n(Kglm
OGEN-2\n20\n(iskfw\nFusl\nV0\nL1\nJulay\nL#eLC_XT\nLS~(\n#H\nT\n20,\ndtivusl\n00\n~1\nIL.\nZD\n(N\netak\nC2C\n04t\nO5TTdekyk\n4z\n~Bucuments Uploaded mn\nHISTZ_HFTy_\nFeg\nIDndM\nA45yeoflyok L\nWeeas\n# kmt9\nDate:\nMGDz\nIwly;', 'CLEAN_output': "Cleaned and Factually Preserved Text:\n\n---\n\n**GYN/OB VITALS MONITORING AND NUTRITIONAL SCREENING FOR OUTPATIENTS**  \n**VITALS MONITORING CHART**  \n\n**Patient Information:**  \n- Name: Atankyha  \n- Age: 24 years  \n- Height: 1.62 meters  \n- Weight: 64 kg  \n- BMI: 24.6  \n- LMP (Last Menstrual Period): 8 November 2028  \n- EDD (Estimated Date of Delivery): 20 June 2029  \n- Husband/Partner Name: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Occupation: Not specified  \n\n**Vital Signs:**  \n- Blood Pressure: 94/63 mmHg  \n- Pulse: 94 beats per minute  \n- SpO2 (Oxygen Saturation): Not specified  \n- Temperature: Not sp ...
# Workflow completed in 13.02s
# Graph compiled successfully
# [values] {'clean_text': "Cleaned and Factually Preserved Text:\n\n---\n\n**GYN/OB VITALS MONITORING AND NUTRITIONAL SCREENING FOR OUTPATIENTS**  \n**VITALS MONITORING CHART**  \n\n**Patient Information:**  \n- Name: Atankyha  \n- Age: 24 years  \n- Height: 1.62 meters  \n- Weight: 64 kg  \n- BMI: 24.6  \n- LMP (Last Menstrual Period): 8 November 2028  \n- EDD (Estimated Date of Delivery): 20 June 2029  \n- Husband/Partner Name: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Occupation: Not specified  \n\n**Vital Signs:**  \n- Blood Pressure: 94/63 mmHg  \n- Pulse: 94 beats per minute  \n- SpO2 (Oxygen Saturation): Not specified  \n- Temperature: Not specified  \n\n**Additional Notes:**  \n- Initials: Not specified  \n- Patient UHID: 9900421492  \n- Group: Not specified  \n- Date of Record: Not specified  \n- Document version: AWFTOBGIDOC/MR/005-00  \n\n---\n\n**ANTENATAL RECORD**  \n**Patient Details:**  \n- UHID No.: 90016YBO S  \n- Age/Gender: 24 years  \n- Consultant's Name: Not specified  \n- Date of Birth: Not specified  \n- Mobile No.: Not specified  \n- Emergency Contact: Not specified  \n- Blood Group: Not specified  \n\n**Important Information:**  \n- LMP: 8 November 2028  \n- EDD: 20 June 2029  \n- Group: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Name: Not specified  \n- Conception: Planned / Unplanned / Spontaneous / Fertility Treatment (not specified)  \n- Marital Duration: Not specified  \n- Consanguinity: Not specified  \n\n**Previous Obstetric History:**  \n| No | Year & Conception | GA at Outcome | Mode of Delivery | Birth Weight | Sex of Child | Complications | Place of Delivery | Health of Child |  \n|----|---------------------|----------------|------------------|--------------|--------------|----------------|------------------|----------------|  \n| 1  | Not specified       | Not specified  | Not specified    | Not specified | Not specified | Not specified | Not specified | Not specified |  \n\n**Gynecology History:**  \n- Gynae Conditions/Treatments: Not specified  \n- Previous Surgery: Not specified  \n- Last Contraceptive Used: Not specified  \n- Menstrual Cycle: Regular / Irregular (not specified)  \n- Last Pap Smear Result: Not specified  \n- Cervical Treatment: Not specified  \n\n**Medical, Surgical & Family History:**  \n- Diabetes: Not specified  \n- Hypertension: Not specified  \n- Thyroid Problems: Not specified  \n- Cardiac Problems: Not specified  \n- Respiratory Problems (Asthma): Not specified  \n- Neurological Problems (Epilepsy): Not specified  \n- TB: Not specified  \n- Back Problems: Not specified  \n- Blood Disorders (DVT/PE): Not specified  \n- Previous Transfusions: Not specified  \n- Fertility Problems: Not specified  \n- Kidney Problems: Not specified  \n- Liver Problems: Not specified  \n- Serious Infections: Not specified  \n- Mental Disorders: Not specified  \n- Vaginal Infections: Not specified  \n- Previous Anesthetic Problems: Not specified  \n- Breast Problems: Not specified  \n- Alcohol Intake: Not specified  \n- Smoking: Not specified  \n- Relevant Family History: Not specified  \n\n---\n\n**OBSTETRIC SUMMARY**  \n| Total Pregnancies | Live Births | Stillbirths | Terminations | Miscarriages (<12 weeks) | Miscarriages (>12 weeks) | Neonatal Deaths | Caesarean Sections | Ectopic Pregnancies | Birthweight <2.5 kg | Other Noted Conditions |  \n|---------------------|--------------|-------------|--------------|--------------------------|-------------------------|-----------------|---------------------|---------------------|---------------------|-----------------------|  \n| Not specified       | Not specified| Not specified| Not specified| Not specified           | Not specified          | Not specified   | Not specified      | Not specified      | Not specified      | Not specified        |  \n\n**Additional Notes:**  \n- Height: Not specified  \n- Weight: Not specified  \n-  ...
# [updates] {'EXTRACT': {'clean_text': "Cleaned and Factually Preserved Text:\n\n---\n\n**GYN/OB VITALS MONITORING AND NUTRITIONAL SCREENING FOR OUTPATIENTS**  \n**VITALS MONITORING CHART**  \n\n**Patient Information:**  \n- Name: Atankyha  \n- Age: 24 years  \n- Height: 1.62 meters  \n- Weight: 64 kg  \n- BMI: 24.6  \n- LMP (Last Menstrual Period): 8 November 2028  \n- EDD (Estimated Date of Delivery): 20 June 2029  \n- Husband/Partner Name: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Occupation: Not specified  \n\n**Vital Signs:**  \n- Blood Pressure: 94/63 mmHg  \n- Pulse: 94 beats per minute  \n- SpO2 (Oxygen Saturation): Not specified  \n- Temperature: Not specified  \n\n**Additional Notes:**  \n- Initials: Not specified  \n- Patient UHID: 9900421492  \n- Group: Not specified  \n- Date of Record: Not specified  \n- Document version: AWFTOBGIDOC/MR/005-00  \n\n---\n\n**ANTENATAL RECORD**  \n**Patient Details:**  \n- UHID No.: 90016YBO S  \n- Age/Gender: 24 years  \n- Consultant's Name: Not specified  \n- Date of Birth: Not specified  \n- Mobile No.: Not specified  \n- Emergency Contact: Not specified  \n- Blood Group: Not specified  \n\n**Important Information:**  \n- LMP: 8 November 2028  \n- EDD: 20 June 2029  \n- Group: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Name: Not specified  \n- Conception: Planned / Unplanned / Spontaneous / Fertility Treatment (not specified)  \n- Marital Duration: Not specified  \n- Consanguinity: Not specified  \n\n**Previous Obstetric History:**  \n| No | Year & Conception | GA at Outcome | Mode of Delivery | Birth Weight | Sex of Child | Complications | Place of Delivery | Health of Child |  \n|----|---------------------|----------------|------------------|--------------|--------------|----------------|------------------|----------------|  \n| 1  | Not specified       | Not specified  | Not specified    | Not specified | Not specified | Not specified | Not specified | Not specified |  \n\n**Gynecology History:**  \n- Gynae Conditions/Treatments: Not specified  \n- Previous Surgery: Not specified  \n- Last Contraceptive Used: Not specified  \n- Menstrual Cycle: Regular / Irregular (not specified)  \n- Last Pap Smear Result: Not specified  \n- Cervical Treatment: Not specified  \n\n**Medical, Surgical & Family History:**  \n- Diabetes: Not specified  \n- Hypertension: Not specified  \n- Thyroid Problems: Not specified  \n- Cardiac Problems: Not specified  \n- Respiratory Problems (Asthma): Not specified  \n- Neurological Problems (Epilepsy): Not specified  \n- TB: Not specified  \n- Back Problems: Not specified  \n- Blood Disorders (DVT/PE): Not specified  \n- Previous Transfusions: Not specified  \n- Fertility Problems: Not specified  \n- Kidney Problems: Not specified  \n- Liver Problems: Not specified  \n- Serious Infections: Not specified  \n- Mental Disorders: Not specified  \n- Vaginal Infections: Not specified  \n- Previous Anesthetic Problems: Not specified  \n- Breast Problems: Not specified  \n- Alcohol Intake: Not specified  \n- Smoking: Not specified  \n- Relevant Family History: Not specified  \n\n---\n\n**OBSTETRIC SUMMARY**  \n| Total Pregnancies | Live Births | Stillbirths | Terminations | Miscarriages (<12 weeks) | Miscarriages (>12 weeks) | Neonatal Deaths | Caesarean Sections | Ectopic Pregnancies | Birthweight <2.5 kg | Other Noted Conditions |  \n|---------------------|--------------|-------------|--------------|--------------------------|-------------------------|-----------------|---------------------|---------------------|---------------------|-----------------------|  \n| Not specified       | Not specified| Not specified| Not specified| Not specified           | Not specified          | Not specified   | Not specified      | Not specified      | Not specified      | Not specified        |  \n\n**Additional Notes:**  \n- Height: Not specified  \n- Weight: Not sp ...
# [values] {'clean_text': "Cleaned and Factually Preserved Text:\n\n---\n\n**GYN/OB VITALS MONITORING AND NUTRITIONAL SCREENING FOR OUTPATIENTS**  \n**VITALS MONITORING CHART**  \n\n**Patient Information:**  \n- Name: Atankyha  \n- Age: 24 years  \n- Height: 1.62 meters  \n- Weight: 64 kg  \n- BMI: 24.6  \n- LMP (Last Menstrual Period): 8 November 2028  \n- EDD (Estimated Date of Delivery): 20 June 2029  \n- Husband/Partner Name: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Occupation: Not specified  \n\n**Vital Signs:**  \n- Blood Pressure: 94/63 mmHg  \n- Pulse: 94 beats per minute  \n- SpO2 (Oxygen Saturation): Not specified  \n- Temperature: Not specified  \n\n**Additional Notes:**  \n- Initials: Not specified  \n- Patient UHID: 9900421492  \n- Group: Not specified  \n- Date of Record: Not specified  \n- Document version: AWFTOBGIDOC/MR/005-00  \n\n---\n\n**ANTENATAL RECORD**  \n**Patient Details:**  \n- UHID No.: 90016YBO S  \n- Age/Gender: 24 years  \n- Consultant's Name: Not specified  \n- Date of Birth: Not specified  \n- Mobile No.: Not specified  \n- Emergency Contact: Not specified  \n- Blood Group: Not specified  \n\n**Important Information:**  \n- LMP: 8 November 2028  \n- EDD: 20 June 2029  \n- Group: Not specified  \n- Occupation: Not specified  \n- Allergies: Not specified  \n- Husband/Partner's Name: Not specified  \n- Conception: Planned / Unplanned / Spontaneous / Fertility Treatment (not specified)  \n- Marital Duration: Not specified  \n- Consanguinity: Not specified  \n\n**Previous Obstetric History:**  \n| No | Year & Conception | GA at Outcome | Mode of Delivery | Birth Weight | Sex of Child | Complications | Place of Delivery | Health of Child |  \n|----|---------------------|----------------|------------------|--------------|--------------|----------------|------------------|----------------|  \n| 1  | Not specified       | Not specified  | Not specified    | Not specified | Not specified | Not specified | Not specified | Not specified |  \n\n**Gynecology History:**  \n- Gynae Conditions/Treatments: Not specified  \n- Previous Surgery: Not specified  \n- Last Contraceptive Used: Not specified  \n- Menstrual Cycle: Regular / Irregular (not specified)  \n- Last Pap Smear Result: Not specified  \n- Cervical Treatment: Not specified  \n\n**Medical, Surgical & Family History:**  \n- Diabetes: Not specified  \n- Hypertension: Not specified  \n- Thyroid Problems: Not specified  \n- Cardiac Problems: Not specified  \n- Respiratory Problems (Asthma): Not specified  \n- Neurological Problems (Epilepsy): Not specified  \n- TB: Not specified  \n- Back Problems: Not specified  \n- Blood Disorders (DVT/PE): Not specified  \n- Previous Transfusions: Not specified  \n- Fertility Problems: Not specified  \n- Kidney Problems: Not specified  \n- Liver Problems: Not specified  \n- Serious Infections: Not specified  \n- Mental Disorders: Not specified  \n- Vaginal Infections: Not specified  \n- Previous Anesthetic Problems: Not specified  \n- Breast Problems: Not specified  \n- Alcohol Intake: Not specified  \n- Smoking: Not specified  \n- Relevant Family History: Not specified  \n\n---\n\n**OBSTETRIC SUMMARY**  \n| Total Pregnancies | Live Births | Stillbirths | Terminations | Miscarriages (<12 weeks) | Miscarriages (>12 weeks) | Neonatal Deaths | Caesarean Sections | Ectopic Pregnancies | Birthweight <2.5 kg | Other Noted Conditions |  \n|---------------------|--------------|-------------|--------------|--------------------------|-------------------------|-----------------|---------------------|---------------------|---------------------|-----------------------|  \n| Not specified       | Not specified| Not specified| Not specified| Not specified           | Not specified          | Not specified   | Not specified      | Not specified      | Not specified      | Not specified        |  \n\n**Additional Notes:**  \n- Height: Not specified  \n- Weight: Not specified  \n-  ...
# Workflow completed in 1.92s
# [DB] Inserted row id=16 at d:\AppsRepository\invoice_generator\invoice.sqlite
# [WARN: ['missing key: vendor', 'missing key: number', 'missing key: date', 'missing key: currency', 'total is null']] file='Token No - VPV-A-0920 - Copy.pdf' vendor=None number=None total=None None
# d:\AppsRepository\invoice_generator\invoice-env\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
\nL1\nJulay\nL#eLC_XT\nLS~(\n#H\nT\n20,\ndtivusl\n00\n~1\nIL.\nZD\n(N\netak\nC2C\n04t\nO5TTdekyk\n4z\n~Bucuments Uploaded mn\nHISTZ_HFTy_\nFeg\nIDndM\nA45yeoflyok L\nWeeas\n# kmt9\nDate:\nMGDz\nIwly;', 'CLEAN_output': "Cleaned plain text version with facts preserved:\n\nPage 1 of 2\n\n**Hysterosalpingography (HSG) Report**\n\n- Patient ID: 249k_\n- Name: Atankyha\n- Age: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Pulse: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- LMP (Last Menstrual Period): 8 November 2028\n- EDD (Expected Date of Delivery): 20 December 2028\n- Husband's Name: Not specified\n- Husband's Occupation: Not specified\n- Phone: 9900421492\n- Blood Group: Not specified\n\n**Outpatient Nutritional Screening & Vitals Monitoring Chart**\n\n- Patient: UHID No: 90016YBO\n- Age/Gender: 24 years\n- Height: 162 cm\n- Weight: 64 kg ...
# [values] {'ocr_text': '8\nL\'\n9\n\n130\n3\n8\n8\n3\n1\n6\n8\n8\n3\n63\n5\n1\n1\n1\n1\n1\n0\n23\n1\n1\n1\n1\n3\n1\n[\n1\n2\n9\n4\n1\n2\n8\n1\nL\n[\n2\nI\n{\n8\n1\n2\n8\nI\n{\n8\n2\nH\n5\nIV\n3\nJ\n\n3\n3\nE\n8\n1\n1\n2\n4\n3\n!\n8\n1\n4\n0\nNI \n9\n8\nWle\n2\n1\n6\nHplh\n8\n2\n7\n8\ng\nIlwh\ng ?\n[\n0\n0\n3\n8\ng\n2\nJ\n3\n8\n{\n1\n5\n1\n0\n1\n2\n8\n1\n0\n1\n8\nL\n#\n8\n2\n6\n1\n3\n8\n2l2g\n8\n1\n8\n0\n8\nO\no\n0\n5\n3\ng\n2\n7\nOBGYN VITALS MONITORING AND\n8 children\nNUTRITIONAL SCREENING FOR OUTPATIENTS\nVITALS MONITORING CHART\nNAME:\nAge:\n249k_\nUo $\nAtankyha\nmiSrq\nHeight:\nT62y\nQ@64<0)\nLMP:\nPatient:\nEDD:\nHusband:\nWEIGHT\nBMI\nNURSE\nBLOOD PRESSURE\nPULSE\nSPOz\nTEMP\nINITIALS\n(mmHg)\n(b/mts)\n(%)\n(*F)\n(Kg)\n(Kglm})\nI4ol &0\nGsbl\n9L6F\n64K4\n44/35\nEb4L\nJof:\n983/Azak\n94,3S\nL36L0\nR4bIK\n4LL\n9$2*E\nL4Lua\naLp-6\nLuiky EHwl\nHo\n@ckn\n3l4k\n44/a\n#8l4L\n0&f.\n927\nshlt-W\n#6/ ~\n9 9+\n91.5\n6p\n664K9\n35.30\nLR ,\n9900421492\nPage 1 of 2\nAWFTOBGIDOC/MR/OO5-00\nAster\nW<tEN4e\nPATIENT \nUHID\nBLOOD\nGROUP\nDATE\nHliy\nlwo \ntallle\n9la:\nEs6kt\n3vd\n8CHildren\nAN
 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Pulse: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- LMP (Last Menstrual Period): 8 November 2028\n- EDD (Expected Date of Delivery): 20 December 2028\n- Husband's Name: Not specified\n- Husband's Occupation: Not specified\n- Phone: 9900421492\n- Blood Group: Not specified\n\n**Outpatient Nutritional Screening & Vitals Monitoring Chart**\n\n- Patient: UHID No: 90016YBO\n- Age/Gender: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24 ...
# Workflow completed in 11.61s
# [values] {'clean_text': "Cleaned plain text version with facts preserved:\n\nPage 1 of 2\n\n**Hysterosalpingography (HSG) Report**\n\n- Patient ID: 249k_\n- Name: Atankyha\n- Age: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Pulse: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- LMP (Last Menstrual Period): 8 November 2028\n- EDD (Expected Date of Delivery): 20 December 2028\n- Husband's Name: Not specified\n- Husband's Occupation: Not specified\n- Phone: 9900421492\n- Blood Group: Not specified\n\n**Outpatient Nutritional Screening & Vitals Monitoring Chart**\n\n- Patient: UHID No: 90016YBO\n- Age/Gender: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Heart Rate: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- Initials: Not specified\n\n**Antenatal Record**\n\n- UHID No: 90016YBO\n- Date of Birth: Not specified\n- Mobile No: Not specified\n- Emergency Contact: Not specified\n- Important Dates:\n  - LMP: 8 November 2028\n  - EDD: 20 December 2028\n- Group: Not specified\n- Occupation: Not specified\n- Allergies: Not specified\n- Husband/Partner's Name: Not specified\n- Occupation: Not specified\n- Marital Duration: Not specified\n- Conception Type: Planned/Unplanned/Spontaneous (not specified)\n- Fertility Treatment: Not specified\n\n**Previous Obstetric History**\n\n| No | Year & Conception | GA at Delivery | Outcome/Mode | Birth Weight | Sex of Child | Complications | Place | Health of Child |\n|-----|---------------------|----------------|--------------|--------------|--------------|----------------|--------|----------------|\n| 1   | Not specified       | Not specified  | Not specified| Not specified| Not specified| Not specified | Not specified | Not specified |\n\n**Gynecology History**\n\n- Conditions/Treatments: Not specified\n- Previous Surgery: Not specified\n- Last Contraceptive Used: Not specified\n- Menstrual Cycle: Regular/Irregular (not specified)\n- Last Pap Smear Result: Not specified\n- Cervical Treatment: Not specified\n\n**Medical/Surgical & Family History**\n\n- Diabetes: Not specified\n- Hypertension: Not specified\n- Thyroid Problems: Not specified\n- Cardiac Problems: Not specified\n- Respiratory Problems (Asthma): Not specified\n- Neurological Problems (Epilepsy): Not specified\n- TB: Not specified\n- Back Problems: Not specified\n- Blood Disorders (DVT/PE): Not specified\n- Previous Transfusions: Not specified\n- Fertility Problems: Not specified\n- Kidney Problems: Not specified\n- Liver Problems: Not specified\n- Serious Infections: Not specified\n- Mental Disorders: Not specified\n- Vaginal Infections: Not specified\n- Previous Anesthetic Problems: Not specified\n- Breast Problems: Not specified\n- Alcohol Intake: Not specified\n- Smoking: Not specified\n- Family History: Not specified\n\n**Obstetric Summary**\n\n- Total Pregnancies: Not specified\n- Live Births: Not specified\n- Stillbirths: Not specified\n- Terminations: Not specified\n- Miscarriages (<12 weeks): Not specified\n- Miscarriages (>12 weeks): Not specified\n- Neonatal Deaths: Not specified\n- Caesarean Sections: Not specified\n- Ectopic Pregnancies: Not specified\n- Birthweight <2.5 kg: Not specified\n- Molar Pregnancies: Not specified\n- Gestation under 37 weeks: Not specified\n\n**Examination Details**\n\n- Height: 162 cm\n- Weight: 64 kg\n- Blood Pressure: 94/63 mmHg\n- Heart Rate: 94 bpm\n- Urine: Not specified\n- Symphysis-Fundal Height (SFH): Not specified\n- Oedema: Not specified\n- Pallor: Not specified\n- Presentation: Not specified\n\n**High-Risk Factors & Action Plan**\n\n- 2nd Dose: Not specified\n- 1st Dose: Not specified\n- Remarks: Not specified\n- Doctor's Signature: Not specified\n\n**Additional Notes**\n\n- Document uploads and other procedural details are not specified or are placeholders.\n-"}
# [updates] {'EXTRACT': {'clean_text': "Cleaned plain text version with facts preserved:\n\nPage 1 of 2\n\n**Hysterosalpingography (HSG) Report**\n\n- Patient ID: 249k_\n- Name: Atankyha\n- Age: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Pulse: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- LMP (Last Menstrual Period): 8 November 2028\n- EDD (Expected Date of Delivery): 20 December 2028\n- Husband's Name: Not specified\n- Husband's Occupation: Not specified\n- Phone: 9900421492\n- Blood Group: Not specified\n\n**Outpatient Nutritional Screening & Vitals Monitoring Chart**\n\n- Patient: UHID No: 90016YBO\n- Age/Gender: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Heart Rate: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- Initials: Not specified\n\n**Antenatal Record**\n\n- UHID No: 90016YBO\n- Date of Birth: Not specified\n- Mobile No: Not specified\n- Emergency Contact: Not specified\n- Important Dates:\n  - LMP: 8 November 2028\n  - EDD: 20 December 2028\n- Group: Not specified\n- Occupation: Not specified\n- Allergies: Not specified\n- Husband/Partner's Name: Not specified\n- Occupation: Not specified\n- Marital Duration: Not specified\n- Conception Type: Planned/Unplanned/Spontaneous (not specified)\n- Fertility Treatment: Not specified\n\n**Previous Obstetric History**\n\n| No | Year & Conception | GA at Delivery | Outcome/Mode | Birth Weight | Sex of Child | Complications | Place | Health of Child |\n|-----|---------------------|----------------|--------------|--------------|--------------|----------------|--------|----------------|\n| 1   | Not specified       | Not specified  | Not specified| Not specified| Not specified| Not specified | Not specified | Not specified |\n\n**Gynecology History**\n\n- Conditions/Treatments: Not specified\n- Previous Surgery: Not specified\n- Last Contraceptive Used: Not specified\n- Menstrual Cycle: Regular/Irregular (not specified)\n- Last Pap Smear Result: Not specified\n- Cervical Treatment: Not specified\n\n**Medical/Surgical & Family History**\n\n- Diabetes: Not specified\n- Hypertension: Not specified\n- Thyroid Problems: Not specified\n- Cardiac Problems: Not specified\n- Respiratory Problems (Asthma): Not specified\n- Neurological Problems (Epilepsy): Not specified\n- TB: Not specified\n- Back Problems: Not specified\n- Blood Disorders (DVT/PE): Not specified\n- Previous Transfusions: Not specified\n- Fertility Problems: Not specified\n- Kidney Problems: Not specified\n- Liver Problems: Not specified\n- Serious Infections: Not specified\n- Mental Disorders: Not specified\n- Vaginal Infections: Not specified\n- Previous Anesthetic Problems: Not specified\n- Breast Problems: Not specified\n- Alcohol Intake: Not specified\n- Smoking: Not specified\n- Family History: Not specified\n\n**Obstetric Summary**\n\n- Total Pregnancies: Not specified\n- Live Births: Not specified\n- Stillbirths: Not specified\n- Terminations: Not specified\n- Miscarriages (<12 weeks): Not specified\n- Miscarriages (>12 weeks): Not specified\n- Neonatal Deaths: Not specified\n- Caesarean Sections: Not specified\n- Ectopic Pregnancies: Not specified\n- Birthweight <2.5 kg: Not specified\n- Molar Pregnancies: Not specified\n- Gestation under 37 weeks: Not specified\n\n**Examination Details**\n\n- Height: 162 cm\n- Weight: 64 kg\n- Blood Pressure: 94/63 mmHg\n- Heart Rate: 94 bpm\n- Urine: Not specified\n- Symphysis-Fundal Height (SFH): Not specified\n- Oedema: Not specified\n- Pallor: Not specified\n- Presentation: Not specified\n\n**High-Risk Factors & Action Plan**\n\n- 2nd Dose: Not specified\n- 1st Dose: Not specified\n- Remarks: Not specified\n- Doctor's Signature: Not specified\n\n**Additional Notes**\n\n- Document uploads and other procedural details are not specified or are placeholders.\n-", 'EXTRACT_output': '{\n  "vendor": null,\n  "number": null,\n  "date": null,\n  "total": null,\n  "currency": null,\n  "line_ite ...
# [values] {'clean_text': "Cleaned plain text version with facts preserved:\n\nPage 1 of 2\n\n**Hysterosalpingography (HSG) Report**\n\n- Patient ID: 249k_\n- Name: Atankyha\n- Age: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Pulse: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- LMP (Last Menstrual Period): 8 November 2028\n- EDD (Expected Date of Delivery): 20 December 2028\n- Husband's Name: Not specified\n- Husband's Occupation: Not specified\n- Phone: 9900421492\n- Blood Group: Not specified\n\n**Outpatient Nutritional Screening & Vitals Monitoring Chart**\n\n- Patient: UHID No: 90016YBO\n- Age/Gender: 24 years\n- Height: 162 cm\n- Weight: 64 kg\n- BMI: 24.6\n- Blood Pressure: 94/63 mmHg\n- Heart Rate: 94 bpm\n- SpO2: 96%\n- Temperature: 36.5°C\n- Initials: Not specified\n\n**Antenatal Record**\n\n- UHID No: 90016YBO\n- Date of Birth: Not specified\n- Mobile No: Not specified\n- Emergency Contact: Not specified\n- Important Dates:\n  - LMP: 8 November 2028\n  - EDD: 20 December 2028\n- Group: Not specified\n- Occupation: Not specified\n- Allergies: Not specified\n- Husband/Partner's Name: Not specified\n- Occupation: Not specified\n- Marital Duration: Not specified\n- Conception Type: Planned/Unplanned/Spontaneous (not specified)\n- Fertility Treatment: Not specified\n\n**Previous Obstetric History**\n\n| No | Year & Conception | GA at Delivery | Outcome/Mode | Birth Weight | Sex of Child | Complications | Place | Health of Child |\n|-----|---------------------|----------------|--------------|--------------|--------------|----------------|--------|----------------|\n| 1   | Not specified       | Not specified  | Not specified| Not specified| Not specified| Not specified | Not specified | Not specified |\n\n**Gynecology History**\n\n- Conditions/Treatments: Not specified\n- Previous Surgery: Not specified\n- Last Contraceptive Used: Not specified\n- Menstrual Cycle: Regular/Irregular (not specified)\n- Last Pap Smear Result: Not specified\n- Cervical Treatment: Not specified\n\n**Medical/Surgical & Family History**\n\n- Diabetes: Not specified\n- Hypertension: Not specified\n- Thyroid Problems: Not specified\n- Cardiac Problems: Not specified\n- Respiratory Problems (Asthma): Not specified\n- Neurological Problems (Epilepsy): Not specified\n- TB: Not specified\n- Back Problems: Not specified\n- Blood Disorders (DVT/PE): Not specified\n- Previous Transfusions: Not specified\n- Fertility Problems: Not specified\n- Kidney Problems: Not specified\n- Liver Problems: Not specified\n- Serious Infections: Not specified\n- Mental Disorders: Not specified\n- Vaginal Infections: Not specified\n- Previous Anesthetic Problems: Not specified\n- Breast Problems: Not specified\n- Alcohol Intake: Not specified\n- Smoking: Not specified\n- Family History: Not specified\n\n**Obstetric Summary**\n\n- Total Pregnancies: Not specified\n- Live Births: Not specified\n- Stillbirths: Not specified\n- Terminations: Not specified\n- Miscarriages (<12 weeks): Not specified\n- Miscarriages (>12 weeks): Not specified\n- Neonatal Deaths: Not specified\n- Caesarean Sections: Not specified\n- Ectopic Pregnancies: Not specified\n- Birthweight <2.5 kg: Not specified\n- Molar Pregnancies: Not specified\n- Gestation under 37 weeks: Not specified\n\n**Examination Details**\n\n- Height: 162 cm\n- Weight: 64 kg\n- Blood Pressure: 94/63 mmHg\n- Heart Rate: 94 bpm\n- Urine: Not specified\n- Symphysis-Fundal Height (SFH): Not specified\n- Oedema: Not specified\n- Pallor: Not specified\n- Presentation: Not specified\n\n**High-Risk Factors & Action Plan**\n\n- 2nd Dose: Not specified\n- 1st Dose: Not specified\n- Remarks: Not specified\n- Doctor's Signature: Not specified\n\n**Additional Notes**\n\n- Document uploads and other procedural details are not specified or are placeholders.\n-", 'EXTRACT_output': '{\n  "vendor": null,\n  "number": null,\n  "date": null,\n  "total": null,\n  "currency": null,\n  "line_items": []\n}',  ...
# Workflow completed in 2.27s
# [DB] Inserted row id=17 at d:\AppsRepository\invoice_generator\invoice.sqlite
# [WARN: ['missing key: vendor', 'missing key: number', 'missing key: date', 'missing key: currency', 'total is null']] file='Token No - VPV-A-0920.pdf' vendor=None number=None total=None None
# ...
# Workflow completed in 2.56s
# [values] {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days'}
# [updates] {'EXTRACT': {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}'}}
# [values] {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}'}
# Workflow completed in 2.35s
# [DB] Inserted row id=18 at d:\AppsRepository\invoice_generator\invoice.sqlite
# [OK] file='invoice_33 - Copy - Copy.png' vendor=Tech Solutions Ltd. number=INV-1033 total=692.83 INR
# d:\AppsRepository\invoice_generator\invoice-env\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [values] {'ocr_text': 'Vendor: Tech Solutions Ltd.\nInvoice Number: INV-1033\nInvoice Date: 2025-09-27\nBilling Address: 123 Example Street, City\nBilling Email:\n@example.com\nSubtotal: 587.14 INR\n105.69 INR\nTotal: 692.8299999999999 INR\nDue Date: 2025-10-13\nPO Number: PO-2033\nNotes: Payment due within 30 days_\nbilling\nTax:'}
# [updates] {'CLEAN': {'ocr_text': 'Vendor: Tech Solutions Ltd.\nInvoice Number: INV-1033\nInvoice Date: 2025-09-27\nBilling Address: 123 Example Street, City\nBilling Email:\n@example.com\nSubtotal: 587.14 INR\n105.69 INR\nTotal: 692.8299999999999 INR\nDue Date: 2025-10-13\nPO Number: PO-2033\nNotes: Payment due within 30 days_\nbilling\nTax:', 'CLEAN_output': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days', 'CLEAN_raw_response': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days'}}
# [values] {'ocr_text': 'Vendor: Tech Solutions Ltd.\nInvoice Number: INV-1033\nInvoice Date: 2025-09-27\nBilling Address: 123 Example Street, City\nBilling Email:\n@example.com\nSubtotal: 587.14 INR\n105.69 INR\nTotal: 692.8299999999999 INR\nDue Date: 2025-10-13\nPO Number: PO-2033\nNotes: Payment due within 30 days_\nbilling\nTax:', 'CLEAN_output': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days', 'CLEAN_raw_response': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days'}
# Workflow completed in 2.43s
# [values] {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days'}
# [updates] {'EXTRACT': {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}'}}
# [values] {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1033  \nInvoice Date: 2025-09-27  \nBilling Address: 123 Example Street, City  \nBilling Email: @example.com  \nSubtotal: 587.14 INR  \nTax: 105.69 INR  \nTotal: 692.83 INR  \nDue Date: 2025-10-13  \nPO Number: PO-2033  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1033",\n  "date": "2025-09-27",\n  "total": 692.83,\n  "currency": "INR",\n  "line_items": []\n}'}
# Workflow completed in 2.25s
# [DB] Inserted row id=19 at d:\AppsRepository\invoice_generator\invoice.sqlite
# [OK] file='invoice_33 - Copy.png' vendor=Tech Solutions Ltd. number=INV-1033 total=692.83 INR
# d:\AppsRepository\invoice_generator\invoice-env\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [values] {'ocr_text': 'Vendor: Global Supplies Inc.\nInvoice Number: INV-1011\nInvoice Date: 2025-09-11\nBilling Address: 123 Example Street, City\nBilling Email: billing@example.com\nSubtotal: 556.92 INR\n100.25 INR\nTotal: 657.17 INR\nDue Date: 2025-10-22\nPO Number: PO-2011\nNotes: Payment due within 30 days_\nTax:'}
# [updates] {'CLEAN': {'ocr_text': 'Vendor: Global Supplies Inc.\nInvoice Number: INV-1011\nInvoice Date: 2025-09-11\nBilling Address: 123 Example Street, City\nBilling Email: billing@example.com\nSubtotal: 556.92 INR\n100.25 INR\nTotal: 657.17 INR\nDue Date: 2025-10-22\nPO Number: PO-2011\nNotes: Payment due within 30 days_\nTax:', 'CLEAN_output': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days', 'CLEAN_raw_response': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days'}}
# [values] {'ocr_text': 'Vendor: Global Supplies Inc.\nInvoice Number: INV-1011\nInvoice Date: 2025-09-11\nBilling Address: 123 Example Street, City\nBilling Email: billing@example.com\nSubtotal: 556.92 INR\n100.25 INR\nTotal: 657.17 INR\nDue Date: 2025-10-22\nPO Number: PO-2011\nNotes: Payment due within 30 days_\nTax:', 'CLEAN_output': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days', 'CLEAN_raw_response': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days'}
# Workflow completed in 2.60s
# [values] {'clean_text': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days'}
# [updates] {'EXTRACT': {'clean_text': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Global Supplies Inc.",\n  "number": "INV-1011",\n  "date": "2025-09-11",\n  "total": 657.17,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Global Supplies Inc.",\n  "number": "INV-1011",\n  "date": "2025-09-11",\n  "total": 657.17,\n  "currency": "INR",\n  "line_items": []\n}'}}
# [values] {'clean_text': 'Vendor: Global Supplies Inc.  \nInvoice Number: INV-1011  \nInvoice Date: 2025-09-11  \nBilling Address: 123 Example Street, City  \nBilling Email: billing@example.com  \nSubtotal: 556.92 INR  \nTax: 100.25 INR  \nTotal: 657.17 INR  \nDue Date: 2025-10-22  \nPO Number: PO-2011  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Global Supplies Inc.",\n  "number": "INV-1011",\n  "date": "2025-09-11",\n  "total": 657.17,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Global Supplies Inc.",\n  "number": "INV-1011",\n  "date": "2025-09-11",\n  "total": 657.17,\n  "currency": "INR",\n  "line_items": []\n}'}
# Workflow completed in 2.10s
# [DB] Inserted row id=20 at d:\AppsRepository\invoice_generator\invoice.sqlite
# [OK] file='invoice_11 - Copy.png' vendor=Global Supplies Inc. number=INV-1011 total=657.17 INR
# d:\AppsRepository\invoice_generator\invoice-env\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [values] {'ocr_text': 'Vendor: Tech Solutions Ltd.\nInvoice Number: INV-1012\nInvoice Date: 2025-09-18\nBilling Address: 123 Example Street, City\nEmail: billing@example.com\nSubtotal: 945.69 INR\n170.22 INR\nTotal: 1115.91 INR\nDue Date: 2025-10-10\nPO Number: PO-2012\nNotes: Payment due within 30 days_\nBilling\nTax:'}
# [updates] {'CLEAN': {'ocr_text': 'Vendor: Tech Solutions Ltd.\nInvoice Number: INV-1012\nInvoice Date: 2025-09-18\nBilling Address: 123 Example Street, City\nEmail: billing@example.com\nSubtotal: 945.69 INR\n170.22 INR\nTotal: 1115.91 INR\nDue Date: 2025-10-10\nPO Number: PO-2012\nNotes: Payment due within 30 days_\nBilling\nTax:', 'CLEAN_output': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days', 'CLEAN_raw_response': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days'}}
# [values] {'ocr_text': 'Vendor: Tech Solutions Ltd.\nInvoice Number: INV-1012\nInvoice Date: 2025-09-18\nBilling Address: 123 Example Street, City\nEmail: billing@example.com\nSubtotal: 945.69 INR\n170.22 INR\nTotal: 1115.91 INR\nDue Date: 2025-10-10\nPO Number: PO-2012\nNotes: Payment due within 30 days_\nBilling\nTax:', 'CLEAN_output': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days', 'CLEAN_raw_response': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days'}
# Workflow completed in 3.32s
# [values] {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days'}
# [updates] {'EXTRACT': {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1012",\n  "date": "2025-09-18",\n  "total": 1115.91,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1012",\n  "date": "2025-09-18",\n  "total": 1115.91,\n  "currency": "INR",\n  "line_items": []\n}'}}
# [values] {'clean_text': 'Vendor: Tech Solutions Ltd.  \nInvoice Number: INV-1012  \nInvoice Date: 2025-09-18  \nBilling Address: 123 Example Street, City  \nEmail: billing@example.com  \nSubtotal: 945.69 INR  \nTax: 170.22 INR  \nTotal: 1115.91 INR  \nDue Date: 2025-10-10  \nPO Number: PO-2012  \nNotes: Payment due within 30 days', 'EXTRACT_output': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1012",\n  "date": "2025-09-18",\n  "total": 1115.91,\n  "currency": "INR",\n  "line_items": []\n}', 'EXTRACT_raw_response': '{\n  "vendor": "Tech Solutions Ltd.",\n  "number": "INV-1012",\n  "date": "2025-09-18",\n  "total": 1115.91,\n  "currency": "INR",\n  "line_items": []\n}'}
# Workflow completed in 3.58s
# [DB] Inserted row id=22 at d:\AppsRepository\invoice_generator\invoice.sqlite
# [OK] file='invoice_12 - Copy.png' vendor=Tech Solutions Ltd. number=INV-1012 total=1115.91 INR
